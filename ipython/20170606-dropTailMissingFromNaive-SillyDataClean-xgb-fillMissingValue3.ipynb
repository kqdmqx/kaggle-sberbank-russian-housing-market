# %% [markdown]
# # import

# %%
import pandas as pd
import numpy as np
import os
import matplotlib.pylab as plt
import seaborn as sns
import xgboost as xgb
import time

# %matplotlib inline

# %% [markdown]
# # load data

# %%
# From here: https://www.kaggle.com/robertoruiz/sberbank-russian-housing-market/dealing-with-multicollinearity/notebook
macro_cols = ["balance_trade", "balance_trade_growth", "eurrub", "average_provision_of_build_contract",
"micex_rgbi_tr", "micex_cbi_tr", "deposits_rate", "mortgage_value", "mortgage_rate",
"income_per_cap", "rent_price_4+room_bus", "museum_visitis_per_100_cap", "apartment_build"]

print len(macro_cols)

macro_keep_cols = ['oil_urals', 'gdp_quart', 'gdp_quart_growth', 'cpi',
              'ppi', 'gdp_deflator', 'balance_trade',
              'balance_trade_growth', 'usdrub', 'eurrub', 'brent',
              'net_capital_export', 'gdp_annual', 'gdp_annual_growth',
              'average_provision_of_build_contract',
              'average_provision_of_build_contract_moscow',
              'rts', 'micex', 'micex_rgbi_tr',
              'micex_cbi_tr', 'deposits_value', 'deposits_growth',
              'deposits_rate', 'mortgage_value',
              'mortgage_growth', 'mortgage_rate',
              'fixed_basket', 'rent_price_4+room_bus', 'rent_price_3room_bus',
              'rent_price_2room_bus', 'rent_price_1room_bus',
              'rent_price_3room_eco',
              'rent_price_2room_eco', 'rent_price_1room_eco']

macro_cols = filter(lambda x: x in macro_keep_cols, macro_cols)
print len(macro_cols)

df_train = pd.read_csv("../input/train.csv", parse_dates=['timestamp'])
df_test = pd.read_csv("../input/test.csv", parse_dates=['timestamp'])
df_macro = pd.read_csv("../input/macro.csv", parse_dates=['timestamp'], usecols=['timestamp'] + macro_cols)

# remove extreme from df_train
df_train.loc[df_train.full_sq == 0, 'full_sq'] = 50
df_test.loc[df_test.full_sq == 0, 'full_sq'] = 50

is_extreme_full_sq = df_train.full_sq > 1000
price_per_sqm = df_train.price_doc/df_train.full_sq
is_extreme_price_per_sqm = (price_per_sqm < 10000) | (price_per_sqm > 500000)
is_extreme = is_extreme_full_sq | is_extreme_price_per_sqm

new_train = df_train.loc[is_extreme.apply(lambda x: not x)].copy()
ex_train = df_train.loc[is_extreme].copy()


# ylog will be log(1+y), as suggested by https://github.com/dmlc/xgboost/issues/446#issuecomment-135555130
ylog_train_all = np.log1p(new_train['price_doc'].values)
id_test = df_test['id']
id_train = new_train['id']
id_train_ex = ex_train['id']

# Build df_all = (df_train+df_test).join(df_macro)
num_train = len(new_train)
df_all = pd.concat([new_train, df_test])
df_all = pd.merge_ordered(df_all, df_macro, on='timestamp', how='left')
df_all.set_index('id', inplace=True)

# 更新build_year
build_year_new = pd.read_csv('../output/feat/BuildYearNew-NaiveXgbMixture-SingleDefault2017060200.csv', index_col='id')
df_all['gaoyl_build_year_state'] = 0
df_all.loc[df_all.build_year.isnull(), 'gaoyl_build_year_state'] = -1
df_all.loc[df_all.build_year.notnull() & df_all.build_year <= 1800, 'gaoyl_build_year_state'] = df_all.loc[df_all.build_year.notnull() & df_all.build_year <= 1800, 'build_year']
df_all.drop(['build_year'], axis=1, inplace=True)
df_all['build_year'] = build_year_new.build_year

# get this from silly game
kitch_is_build_year = [13117]
df_all.ix[kitch_is_build_year, "build_year"] = df_all.ix[kitch_is_build_year, "kitch_sq"]
df_all['gaoyl_time_offset'] = df_all.timestamp.dt.year - df_all.build_year

# 更新state
state_new = pd.read_csv('../output/feat/StateNew-NaiveXgbMixture-SingleDefault2017060402-WithPrice.csv', index_col='id')
df_all['gaoyl_state_state'] = 0
df_all.loc[df_all.state.isin((1, 2, 3, 4)), 'gaoyl_state_state'] = 1
df_all['state'] = state_new.state

# 更新max_floor
max_floor_new = pd.read_csv('../output/feat/MaxFloor-NaiveXgbMixture-SingleDefault2017060400-WithPrice.csv', index_col='id')
df_all['gaoyl_max_floor_state'] = -1
df_all.loc[df_all.max_floor.isnull(), 'gaoyl_max_floor_state'] = -2
max_floor_wong = df_all.max_floor < df_all.floor
df_all.loc[max_floor_wong, 'gaoyl_max_floor_state'] = df_all.loc[max_floor_wong, 'max_floor']
df_all['max_floor'] = max_floor_new.max_floor

# Add month-year
# 新特征 哪年哪月（交易量）
month_year = (df_all.timestamp.dt.month + df_all.timestamp.dt.year * 100)
month_year_cnt_map = month_year.value_counts().to_dict()
df_all['month_year_cnt'] = month_year.map(month_year_cnt_map)

# Add week-year count
# 新特征 一年中的第几周（交易量）
week_year = (df_all.timestamp.dt.weekofyear + df_all.timestamp.dt.year * 100)
week_year_cnt_map = week_year.value_counts().to_dict()
df_all['week_year_cnt'] = week_year.map(week_year_cnt_map)

# Add month and day-of-week
# 新特征 几月份（交易 ）和 星期几（交易）
df_all['month'] = df_all.timestamp.dt.month
df_all['dow'] = df_all.timestamp.dt.dayofweek

# Other feature engineering
df_all['rel_floor'] = df_all['floor'] / df_all['max_floor'].astype(float)
df_all['rel_kitch_sq'] = df_all['kitch_sq'] / df_all['full_sq'].astype(float)

sub_area_map = df_all.sub_area.value_counts().to_dict()
df_all['gaoyl_subarea_cnt'] = df_all.sub_area.map(sub_area_map)

# 删除多余的列
to_drop = ['price_doc', 'timestamp', 'gaoyl_rest_sq']
df_all.drop(filter(lambda x: x in df_all.columns, to_drop), axis=1, inplace=True)

# Deal with categorical values
df_numeric = df_all.select_dtypes(exclude=['object'])
df_obj = df_all.select_dtypes(include=['object']).copy()

for c in df_obj:
    df_obj[c] = pd.factorize(df_obj[c])[0]

df_values = pd.concat([df_numeric, df_obj], axis=1)

# Convert to numpy values
X_all = df_values.values
print(X_all.shape)

# Create a validation set, with last 20% of data
num_val = int(num_train * 0.2)

X_train_all = X_all[:num_train]
X_train = X_all[:num_train-num_val]
X_val = X_all[num_train-num_val:num_train]
ylog_train = ylog_train_all[:-num_val]
ylog_val = ylog_train_all[-num_val:]

X_test = X_all[num_train:]

df_columns = df_values.columns

print('X_train_all shape is', X_train_all.shape)
print('X_train shape is', X_train.shape)
print('y_train shape is', ylog_train.shape)
print('X_val shape is', X_val.shape)
print('y_val shape is', ylog_val.shape)
print('X_test shape is', X_test.shape)
# Out:
# 13
# 10
# D:\Anaconda2\lib\site-packages\ipykernel\__main__.py:65: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate_ix
# D:\Anaconda2\lib\site-packages\pandas\core\indexing.py:992: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate_ix
#   return getattr(section, self.name)[new_key]
# (38063L, 310L)
# ('X_train_all shape is', (30401L, 310L))
# ('X_train shape is', (24321L, 310L))
# ('y_train shape is', (24321L,))
# ('X_val shape is', (6080L, 310L))
# ('y_val shape is', (6080L,))
# ('X_test shape is', (7662L, 310L))

# %% [markdown]
# # xgboost single
#
# * naive-xgb Best iteration : [247]	val-rmse:0.420493
# * build_year : [239]	val-rmse:0.420128
# * state-single00 :[220]	val-rmse:0.421898
# * state-single01 : [278]	val-rmse:0.422102
# * state-single02-withPrice : [258]	val-rmse:0.421543
# * max_floor-single00: [290]	val-rmse:0.419859
# * dropTailMissingAndIgnoreMultico:[314]	val-rmse:0.420959
# * dropTailMissingAndIgnoreMultico-SillyDataClean-RemoveExtremeTrainSample:[313]	val-rmse:0.418111
# * dropTailMissingFromNaive-SillyDataClean-RemoveExtremeTrainSample: [270]	val-rmse:0.418366

# %% [markdown]
# ## best round + 20

# %%
dtrain_all = xgb.DMatrix(X_train_all, ylog_train_all, feature_names=df_columns)
dtrain = xgb.DMatrix(X_train, ylog_train, feature_names=df_columns)
dval = xgb.DMatrix(X_val, ylog_val, feature_names=df_columns)
dtest = xgb.DMatrix(X_test, feature_names=df_columns)

xgb_params = {
    'eta': 0.04,
    'max_depth': 5,
    'subsample': 1.0,
    'colsample_bytree': 0.7,
    'objective': 'reg:linear',
    'eval_metric': 'rmse',
    'silent': 1
}

# Uncomment to tune XGB `num_boost_rounds`
partial_model = xgb.train(xgb_params, dtrain, evals=[(dval, 'val')],
                          num_boost_round=1000,
                          early_stopping_rounds=25,
                          verbose_eval=25)

num_boost_round = partial_model.best_iteration
# Out:
# [0]	val-rmse:14.627
# Will train until val-rmse hasn't improved in 25 rounds.
# [25]	val-rmse:5.35346
# [50]	val-rmse:2.03069
# [75]	val-rmse:0.878084
# [100]	val-rmse:0.532925
# [125]	val-rmse:0.448809
# [150]	val-rmse:0.428731
# [175]	val-rmse:0.42266
# [200]	val-rmse:0.420293
# [225]	val-rmse:0.419247
# [250]	val-rmse:0.418692
# [275]	val-rmse:0.41877
# Stopping. Best iteration:
# [270]	val-rmse:0.418366

# %% [markdown]
# ## best round + 20 feature importance

# %%
fig, ax = plt.subplots(1, 1, figsize=(8, 16))
xgb.plot_importance(partial_model, max_num_features=50, height=0.5, ax=ax)

# %%
partial_model.get_fscore()['kitch_sq']
# Out:
# 64

# %% [markdown]
# ## correlation analysis

# %%
partial_model_fscore = partial_model.get_fscore()
partial_model_fscore = sorted(partial_model_fscore.items(), key=lambda x: x[1], reverse=True)
top_features = map(lambda x: x[0], partial_model_fscore[:35])
# top_features.append('price_doc')

corr_matt = df_all[top_features].corr()
mask = np.array(corr_matt)
mask[np.tril_indices_from(mask)] = False
plt.figure(figsize=(35, 35))
sns.heatmap(corr_matt, mask=mask, vmax=.8, square=True, annot=True)
# Out:
# D:\Anaconda2\lib\site-packages\seaborn\matrix.py:143: DeprecationWarning: elementwise == comparison failed; this will raise an error in the future.
#   if xticklabels == []:
# D:\Anaconda2\lib\site-packages\seaborn\matrix.py:151: DeprecationWarning: elementwise == comparison failed; this will raise an error in the future.
#   if yticklabels == []:

# %% [markdown]
# ## best round

# %%
num_boost_round = partial_model.best_iteration
model = xgb.train(dict(xgb_params, silent=0), dtrain_all, num_boost_round=num_boost_round)

# %% [markdown]
# ## best round feature importance

# %%
fig, ax = plt.subplots(1, 1, figsize=(8, 16))
xgb.plot_importance(model, max_num_features=50, height=0.5, ax=ax)

# %% [markdown]
# ## best round prediction

# %%
ylog_pred = model.predict(dtest)
y_pred = np.exp(ylog_pred) - 1

df_sub = pd.DataFrame({'id': id_test, 'price_doc': y_pred})

df_sub.to_csv('../output/single/Submission-NaiveXgb-WithPredictedBuildYear-SingleModel.csv', index=False)

# %% [markdown]
# # xgboost stacking
#
# 1. origin
#
# [0]	val-rmse:14.3587
# Will train until val-rmse hasn't improved in 25 rounds.
# [25]	val-rmse:4.00887
# [50]	val-rmse:1.20024
# [75]	val-rmse:0.558586
# [100]	val-rmse:0.47248
# [125]	val-rmse:0.463847
# [150]	val-rmse:0.462329
# [175]	val-rmse:0.461818
# [200]	val-rmse:0.461315
# [225]	val-rmse:0.461335
# [250]	val-rmse:0.460991
# Stopping. Best iteration:
# [240]	val-rmse:0.460887
#
# [0]	val-rmse:14.3798
# Will train until val-rmse hasn't improved in 25 rounds.
# [25]	val-rmse:4.02935
# [50]	val-rmse:1.21488
# [75]	val-rmse:0.560391
# [100]	val-rmse:0.465031
# [125]	val-rmse:0.453676
# [150]	val-rmse:0.451134
# [175]	val-rmse:0.450191
# [200]	val-rmse:0.449949
# [225]	val-rmse:0.449857
# [250]	val-rmse:0.44971
# [275]	val-rmse:0.44978
# Stopping. Best iteration:
# [262]	val-rmse:0.449558
#
# [0]	val-rmse:14.3561
# Will train until val-rmse hasn't improved in 25 rounds.
# [25]	val-rmse:4.00452
# [50]	val-rmse:1.19977
# [75]	val-rmse:0.566417
# [100]	val-rmse:0.48349
# [125]	val-rmse:0.475044
# [150]	val-rmse:0.47328
# [175]	val-rmse:0.472655
# [200]	val-rmse:0.472268
# [225]	val-rmse:0.47163
# [250]	val-rmse:0.471275
# [275]	val-rmse:0.471096
# [300]	val-rmse:0.471008
# Stopping. Best iteration:
# [287]	val-rmse:0.470986
#
# [0]	val-rmse:14.3779
# Will train until val-rmse hasn't improved in 25 rounds.
# [25]	val-rmse:4.02287
# [50]	val-rmse:1.20794
# [75]	val-rmse:0.556847
# [100]	val-rmse:0.465476
# [125]	val-rmse:0.454908
# [150]	val-rmse:0.452888
# [175]	val-rmse:0.452301
# [200]	val-rmse:0.451806
# [225]	val-rmse:0.451739
# [250]	val-rmse:0.451515
# [275]	val-rmse:0.451327
# [300]	val-rmse:0.451436
# Stopping. Best iteration:
# [280]	val-rmse:0.451242
#
# [0]	val-rmse:14.3603
# Will train until val-rmse hasn't improved in 25 rounds.
# [25]	val-rmse:4.01049
# [50]	val-rmse:1.20299
# [75]	val-rmse:0.561595
# [100]	val-rmse:0.475948
# [125]	val-rmse:0.467475
# [150]	val-rmse:0.465742
# [175]	val-rmse:0.465219
# [200]	val-rmse:0.46509
# [225]	val-rmse:0.46458
# [250]	val-rmse:0.464638
# Stopping. Best iteration:
# [228]	val-rmse:0.464534
#
# 2. value2
#
# [0]	val-rmse:14.3587
# Will train until val-rmse hasn't improved in 25 rounds.
# [25]	val-rmse:4.00855
# [50]	val-rmse:1.20088
# [75]	val-rmse:0.559749
# [100]	val-rmse:0.473471
# [125]	val-rmse:0.464586
# [150]	val-rmse:0.462567
# [175]	val-rmse:0.462321
# [200]	val-rmse:0.461471
# [225]	val-rmse:0.460937
# [250]	val-rmse:0.460699
# [275]	val-rmse:0.460577
# [300]	val-rmse:0.460355
# Stopping. Best iteration:
# [294]	val-rmse:0.460325
#
# [0]	val-rmse:14.3798
# Will train until val-rmse hasn't improved in 25 rounds.
# [25]	val-rmse:4.02896
# [50]	val-rmse:1.21475
# [75]	val-rmse:0.559898
# [100]	val-rmse:0.464205
# [125]	val-rmse:0.452462
# [150]	val-rmse:0.450162
# [175]	val-rmse:0.449025
# [200]	val-rmse:0.448769
# [225]	val-rmse:0.448474
# [250]	val-rmse:0.448476
# [275]	val-rmse:0.448134
# [300]	val-rmse:0.448173
# Stopping. Best iteration:
# [277]	val-rmse:0.448117
#
# [0]	val-rmse:14.3561
# Will train until val-rmse hasn't improved in 25 rounds.
# [25]	val-rmse:4.0045
# [50]	val-rmse:1.19996
# [75]	val-rmse:0.565932
# [100]	val-rmse:0.482486
# [125]	val-rmse:0.474065
# [150]	val-rmse:0.472326
# [175]	val-rmse:0.471732
# [200]	val-rmse:0.471158
# [225]	val-rmse:0.470968
# [250]	val-rmse:0.470586
# [275]	val-rmse:0.470861
# Stopping. Best iteration:
# [250]	val-rmse:0.470586
#
# [0]	val-rmse:14.3779
# Will train until val-rmse hasn't improved in 25 rounds.
# [25]	val-rmse:4.02345
# [50]	val-rmse:1.20816
# [75]	val-rmse:0.557108
# [100]	val-rmse:0.464468
# [125]	val-rmse:0.453604
# [150]	val-rmse:0.451546
# [175]	val-rmse:0.450518
# [200]	val-rmse:0.449941
# [225]	val-rmse:0.449746
# [250]	val-rmse:0.449603
# [275]	val-rmse:0.449567
# [300]	val-rmse:0.449531
# Stopping. Best iteration:
# [282]	val-rmse:0.449409
#
# [0]	val-rmse:14.3603
# Will train until val-rmse hasn't improved in 25 rounds.
# [25]	val-rmse:4.01079
# [50]	val-rmse:1.20288
# [75]	val-rmse:0.561848
# [100]	val-rmse:0.475332
# [125]	val-rmse:0.466206
# [150]	val-rmse:0.465004
# [175]	val-rmse:0.464846
# [200]	val-rmse:0.464602
# [225]	val-rmse:0.464702
# Stopping. Best iteration:
# [210]	val-rmse:0.464457
#
#
# 3. drop

# %%
import sys
sys.path.append('..')
from my_py_models.stacking import Stacking
from my_py_models.my_xgb_classifier import MyXgbClassifier

# %%
xgb_params = {
    'eta': 0.04,
    'max_depth': 5,
    'subsample': 1.0,
    'colsample_bytree': 0.7,
    'objective': 'reg:linear',
    'eval_metric': 'rmse',
    'silent': 1
}

clf = MyXgbClassifier(xgb_params)
stacking = Stacking(5, [clf])
pred_oof, pred_test = stacking.fit_predict(X_train_all, ylog_train_all, X_test)
# Out:
# [0]	val-rmse:14.5097
# Will train until val-rmse hasn't improved in 25 rounds.
# [25]	val-rmse:5.24759
# [50]	val-rmse:1.94162
# [75]	val-rmse:0.824209
# [100]	val-rmse:0.52611
# [125]	val-rmse:0.471731
# [150]	val-rmse:0.462781
# [175]	val-rmse:0.461078
# [200]	val-rmse:0.460564
# [225]	val-rmse:0.460317
# [250]	val-rmse:0.459827
# [275]	val-rmse:0.459522
# Stopping. Best iteration:
# [268]	val-rmse:0.45944
#
# [0]	val-rmse:14.5308
# Will train until val-rmse hasn't improved in 25 rounds.
# [25]	val-rmse:5.26911
# [50]	val-rmse:1.95986
# [75]	val-rmse:0.835138
# [100]	val-rmse:0.52528
# [125]	val-rmse:0.464267
# [150]	val-rmse:0.452786
# [175]	val-rmse:0.4496
# [200]	val-rmse:0.448215
# [225]	val-rmse:0.447832
# [250]	val-rmse:0.447584
# [275]	val-rmse:0.447272
# [300]	val-rmse:0.447476
# Stopping. Best iteration:
# [276]	val-rmse:0.44726
#
# [0]	val-rmse:14.5072
# Will train until val-rmse hasn't improved in 25 rounds.
# [25]	val-rmse:5.24301
# [50]	val-rmse:1.93902
# [75]	val-rmse:0.826692
# [100]	val-rmse:0.533812
# [125]	val-rmse:0.482441
# [150]	val-rmse:0.474427
# [175]	val-rmse:0.472761
# [200]	val-rmse:0.472059
# [225]	val-rmse:0.471599
# [250]	val-rmse:0.471175
# [275]	val-rmse:0.471228
# [300]	val-rmse:0.471045
# [325]	val-rmse:0.470678
# [350]	val-rmse:0.470566
# Stopping. Best iteration:
# [328]	val-rmse:0.470513
#
# [0]	val-rmse:14.5289
# Will train until val-rmse hasn't improved in 25 rounds.
# [25]	val-rmse:5.2631
# [50]	val-rmse:1.95256
# [75]	val-rmse:0.829088
# [100]	val-rmse:0.522917
# [125]	val-rmse:0.464733
# [150]	val-rmse:0.454472
# [175]	val-rmse:0.45176
# [200]	val-rmse:0.450192
# [225]	val-rmse:0.450084
# [250]	val-rmse:0.449715
# [275]	val-rmse:0.44956
# Stopping. Best iteration:
# [274]	val-rmse:0.449521
#
# [0]	val-rmse:14.5113
# Will train until val-rmse hasn't improved in 25 rounds.
# [25]	val-rmse:5.24986
# [50]	val-rmse:1.94374
# [75]	val-rmse:0.827222
# [100]	val-rmse:0.528982
# [125]	val-rmse:0.475283
# [150]	val-rmse:0.466865
# [175]	val-rmse:0.465036
# [200]	val-rmse:0.464273
# [225]	val-rmse:0.463809
# [250]	val-rmse:0.46357
# [275]	val-rmse:0.463227
# [300]	val-rmse:0.463268
# Stopping. Best iteration:
# [275]	val-rmse:0.463227

# %% [markdown]
# ## oof value
# 1. value1 0.460019246439
# 2. value2 0.458690181301
# 3. value3 0.458554355046
# 4. Ignore 0.458115434247

# %%
from sklearn.metrics import mean_squared_error

print pred_oof.shape
print pred_test.shape

for pred_oof_single in pred_oof.T:
    print np.sqrt(mean_squared_error(pred_oof_single, ylog_train_all))
# Out:
# (30471L, 1L)
# (7662L, 1L)
# 0.458115434247

# %% [markdown]
# ## stacking prediction

# %%
y_pred = np.exp(pred_test[:, 0]) - 1
y_oof = np.exp(pred_oof[:, 0]) - 1

df_sub = pd.DataFrame({'id': id_test, 'price_doc': y_pred})
df_sub.to_csv('../output/stacking/Submission-DropTailMissingAndIgnoreMulXgb-MissingValue3-Stacking-2017060600-Test.csv', index=False)

df_oof = pd.DataFrame({'id': id_train, 'price_doc': y_oof})
df_oof.to_csv('../output/stacking/Submission-DropTailMissingAndIgnoreMulXgb-MissingValue3-Stacking-2017060600-OutOfFold.csv', index=False)

# %% [markdown]
# # xgboost stacking2
# 1. oof rmse: 0.459703076195
# 2. oof removeEx: 0.450736358701
# 3. keep Naive removeEx: 0.450761234184

# %%
import sys
sys.path.append('..')
from my_py_models.stacking import Stacking
from my_py_models.my_xgb_classifier import MyXgbClassifier
from my_py_models.my_xgb_classifier2 import MyXgbClassifier2
from sklearn.metrics import mean_squared_error

xgb_params = {
    'eta': 0.04,
    'max_depth': 5,
    'subsample': 1.0,
    'colsample_bytree': 0.7,
    'objective': 'reg:linear',
    'eval_metric': 'rmse',
    'silent': 1
}

clf = MyXgbClassifier2(xgb_params)
stacking = Stacking(5, [clf])
pred_oof, pred_test = stacking.fit_predict(X_train_all, ylog_train_all, X_test)

for pred_oof_single in pred_oof.T:
    print np.sqrt(mean_squared_error(pred_oof_single, ylog_train_all))

y_pred = np.exp(pred_test[:, 0]) - 1
y_oof = np.exp(pred_oof[:, 0]) - 1

df_sub = pd.DataFrame({'id': id_test, 'price_doc': y_pred})
df_sub.to_csv('../output/stacking/Submission-DropTailMissingFromNaiveXgb-SillyDataCleanRemoveExtreme-MissingValue3-Stacking2-2017060700-Test.csv', index=False)

df_oof = pd.DataFrame({'id': id_train, 'price_doc': y_oof})
df_oof.to_csv('../output/stacking/Submission-DropTailMissingFromNaiveXgb-SillyDataCleanRemoveExtreme-MissingValue3-Stacking2-20170606700-OutOfFold-ToBeFixed.csv', index=False)
# Out:
# [0]	val-rmse:14.5244
# Will train until val-rmse hasn't improved in 25 rounds.
# [25]	val-rmse:5.26022
# [50]	val-rmse:1.95
# [75]	val-rmse:0.824902
# [100]	val-rmse:0.516935
# [125]	val-rmse:0.458212
# [150]	val-rmse:0.448298
# [175]	val-rmse:0.446046
# [200]	val-rmse:0.445512
# [225]	val-rmse:0.445237
# [250]	val-rmse:0.44518
# [275]	val-rmse:0.445027
# Stopping. Best iteration:
# [264]	val-rmse:0.444894
#
# [0]	val-rmse:14.5134
# Will train until val-rmse hasn't improved in 25 rounds.
# [25]	val-rmse:5.24725
# [50]	val-rmse:1.93995
# [75]	val-rmse:0.821522
# [100]	val-rmse:0.522038
# [125]	val-rmse:0.468187
# [150]	val-rmse:0.460075
# [175]	val-rmse:0.4582
# [200]	val-rmse:0.457435
# [225]	val-rmse:0.457046
# [250]	val-rmse:0.456816
# [275]	val-rmse:0.456867
# Stopping. Best iteration:
# [252]	val-rmse:0.456642
#
# [0]	val-rmse:14.5136
# Will train until val-rmse hasn't improved in 25 rounds.
# [25]	val-rmse:5.2502
# [50]	val-rmse:1.9406
# [75]	val-rmse:0.8195
# [100]	val-rmse:0.515947
# [125]	val-rmse:0.459957
# [150]	val-rmse:0.450146
# [175]	val-rmse:0.44815
# [200]	val-rmse:0.447225
# [225]	val-rmse:0.446682
# [250]	val-rmse:0.446043
# [275]	val-rmse:0.445514
# [300]	val-rmse:0.44545
# Stopping. Best iteration:
# [294]	val-rmse:0.445391
#
# [0]	val-rmse:14.5258
# Will train until val-rmse hasn't improved in 25 rounds.
# [25]	val-rmse:5.26346
# [50]	val-rmse:1.95309
# [75]	val-rmse:0.82449
# [100]	val-rmse:0.510727
# [125]	val-rmse:0.449071
# [150]	val-rmse:0.437801
# [175]	val-rmse:0.435136
# [200]	val-rmse:0.434307
# [225]	val-rmse:0.433971
# [250]	val-rmse:0.433599
# Stopping. Best iteration:
# [246]	val-rmse:0.433538
#
# [0]	val-rmse:14.5193
# Will train until val-rmse hasn't improved in 25 rounds.
# [25]	val-rmse:5.25245
# [50]	val-rmse:1.94301
# [75]	val-rmse:0.82112
# [100]	val-rmse:0.517439
# [125]	val-rmse:0.461202
# [150]	val-rmse:0.452464
# [175]	val-rmse:0.45014
# [200]	val-rmse:0.449206
# [225]	val-rmse:0.448713
# [250]	val-rmse:0.448146
# [275]	val-rmse:0.447858
# [300]	val-rmse:0.447482
# [325]	val-rmse:0.447278
# [350]	val-rmse:0.446993
# [375]	val-rmse:0.44686
# [400]	val-rmse:0.447142
# Stopping. Best iteration:
# [375]	val-rmse:0.44686
#
# 0.450761234184

# %% [markdown]
# # xgboost stacking3
# 1. oof rmse 0.458261394991

# %%
from my_py_models.my_xgb_classifier3 import MyXgbClassifier3

xgb_params = {
    'eta': 0.04,
    'max_depth': 5,
    'subsample': 1.0,
    'colsample_bytree': 0.7,
    'objective': 'reg:linear',
    'eval_metric': 'rmse',
    'silent': 1
}

clf = MyXgbClassifier3(xgb_params)
stacking = Stacking(5, [clf])
pred_oof, pred_test = stacking.fit_predict(X_train_all, ylog_train_all, X_test)

for pred_oof_single in pred_oof.T:
    print np.sqrt(mean_squared_error(pred_oof_single, ylog_train_all))
    
y_pred = np.exp(pred_test[:, 0]) - 1
y_oof = np.exp(pred_oof[:, 0]) - 1

df_sub = pd.DataFrame({'id': id_test, 'price_doc': y_pred})
df_sub.to_csv('../output/stacking/Submission-DropTailMissingAndIgnoreMulXgb-MissingValue3-Stacking3-2017060600-Test.csv', index=False)

df_oof = pd.DataFrame({'id': id_train, 'price_doc': y_oof})
df_oof.to_csv('../output/stacking/Submission-DropTailMissingAndIgnoreMulXgb-MissingValue3-Stacking3-2017060600-OutOfFold.csv', index=False)
# Out:
# [0]	val-rmse:14.522
# Will train until val-rmse hasn't improved in 25 rounds.
# [25]	val-rmse:5.25814
# [50]	val-rmse:1.95049
# [75]	val-rmse:0.828646
# [100]	val-rmse:0.523812
# [125]	val-rmse:0.465727
# [150]	val-rmse:0.455148
# [175]	val-rmse:0.452646
# [200]	val-rmse:0.451499
# [225]	val-rmse:0.450892
# [250]	val-rmse:0.450366
# Stopping. Best iteration:
# [249]	val-rmse:0.450352
#
# [0]	val-rmse:14.5047
# Will train until val-rmse hasn't improved in 25 rounds.
# [25]	val-rmse:5.24635
# [50]	val-rmse:1.94227
# [75]	val-rmse:0.824212
# [100]	val-rmse:0.524774
# [125]	val-rmse:0.470952
# [150]	val-rmse:0.462821
# [175]	val-rmse:0.461373
# [200]	val-rmse:0.460839
# [225]	val-rmse:0.460421
# [250]	val-rmse:0.460147
# [275]	val-rmse:0.460066
# Stopping. Best iteration:
# [260]	val-rmse:0.459802
#
# [0]	val-rmse:14.5142
# Will train until val-rmse hasn't improved in 25 rounds.
# [25]	val-rmse:5.24959
# [50]	val-rmse:1.9427
# [75]	val-rmse:0.827884
# [100]	val-rmse:0.531743
# [125]	val-rmse:0.478175
# [150]	val-rmse:0.469189
# [175]	val-rmse:0.467429
# [200]	val-rmse:0.466669
# [225]	val-rmse:0.466477
# [250]	val-rmse:0.465907
# [275]	val-rmse:0.465566
# [300]	val-rmse:0.465381
# [325]	val-rmse:0.465285
# Stopping. Best iteration:
# [310]	val-rmse:0.465113
#
# [0]	val-rmse:14.5021
# Will train until val-rmse hasn't improved in 25 rounds.
# [25]	val-rmse:5.23928
# [50]	val-rmse:1.93491
# [75]	val-rmse:0.822085
# [100]	val-rmse:0.531284
# [125]	val-rmse:0.481049
# [150]	val-rmse:0.473926
# [175]	val-rmse:0.472566
# [200]	val-rmse:0.471604
# [225]	val-rmse:0.471249
# [250]	val-rmse:0.470794
# [275]	val-rmse:0.470561
# [300]	val-rmse:0.470221
# [325]	val-rmse:0.470147
# [350]	val-rmse:0.469912
# Stopping. Best iteration:
# [344]	val-rmse:0.469902
#
# [0]	val-rmse:14.5141
# Will train until val-rmse hasn't improved in 25 rounds.
# [25]	val-rmse:5.25375
# [50]	val-rmse:1.94931
# [75]	val-rmse:0.832031
# [100]	val-rmse:0.531726
# [125]	val-rmse:0.476107
# [150]	val-rmse:0.466526
# [175]	val-rmse:0.464021
# [200]	val-rmse:0.463053
# [225]	val-rmse:0.46256
# [250]	val-rmse:0.462181
# [275]	val-rmse:0.461958
# [300]	val-rmse:0.462101
# Stopping. Best iteration:
# [275]	val-rmse:0.461958
#
# 0.458261394991
